# %%
import pandas as pd

# %%
df = pd.read_csv('edad poblacion por periodo.csv', delimiter = ';')

# %%
df
# Out:
#            Provincias            Edad  Periodo  Total  Porcentaje
# 0      Total Nacional   65 y más años     2022  20,08       20.08
# 1      Total Nacional   65 y más años     2021  19,77       19.77
# 2      Total Nacional   65 y más años     2020  19,58       19.58
# 3      Total Nacional   65 y más años     2019  19,40       19.40
# 4      Total Nacional   65 y más años     2018  19,20       19.20
# ...               ...             ...      ...    ...         ...
# 20347      52 Melilla  100 y más años     1979   0,02        0.02
# 20348      52 Melilla  100 y más años     1978   0,02        0.02
# 20349      52 Melilla  100 y más años     1977   0,02        0.02
# 20350      52 Melilla  100 y más años     1976   0,02        0.02
# 20351      52 Melilla  100 y más años     1975   0,02        0.02
#
# [20352 rows x 5 columns]

# %%
selec = df['Provincias'] == 'Total Nacional'

# %%
selec2 = df['Periodo'] == 2022

# %%
dfs = df[selec & selec2]

# %%
a = dfs['Edad'].values

# %%
dfs
# Out:
#          Provincias            Edad  Periodo  Total
# 0    Total Nacional   65 y más años     2022  20,08
# 48   Total Nacional   70 y más años     2022  14,70
# 96   Total Nacional   75 y más años     2022   9,98
# 144  Total Nacional   80 y más años     2022   6,08
# 192  Total Nacional   85 y más años     2022   3,41
# 240  Total Nacional   90 y más años     2022   1,27
# 288  Total Nacional   95 y más años     2022   0,29
# 336  Total Nacional  100 y más años     2022   0,03

# %%
b = dfs['Total'].values

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.barh(a,b)
ax.set_title('Porcentaje población por franja de edad')
ax.grid(axis='x')
None

# %%
b
# Out:
# array(['20,08', '14,70', '9,98', '6,08', '3,41', '1,27', '0,29', '0,03'],
#       dtype=object)

# %%
a
# Out:
# array(['65 y más años', '70 y más años', '75 y más años', '80 y más años',
#        '85 y más años', '90 y más años', '95 y más años',
#        '100 y más años'], dtype=object)

# %%
def pasarFloat(x):
    if ',' in x:
        a = x.split(',')
        ent = a[0]
        frac = a[1]
        return float(ent+'.'+frac)
    else:
        return float(x)

# %%
dfs['Porcentaje'] = dfs['Total'].map(pasarFloat)
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_23392\4055748679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs['Porcentaje'] = dfs['Total'].map(pasarFloat)

# %%
dfs
# Out:
#          Provincias            Edad  Periodo  Total  Porcentaje
# 0    Total Nacional   65 y más años     2022  20,08       20.08
# 48   Total Nacional   70 y más años     2022  14,70       14.70
# 96   Total Nacional   75 y más años     2022   9,98        9.98
# 144  Total Nacional   80 y más años     2022   6,08        6.08
# 192  Total Nacional   85 y más años     2022   3,41        3.41
# 240  Total Nacional   90 y más años     2022   1,27        1.27
# 288  Total Nacional   95 y más años     2022   0,29        0.29
# 336  Total Nacional  100 y más años     2022   0,03        0.03

# %%
b = dfs['Porcentaje'].values

# %%
a
# Out:
# array(['65 y más años', '70 y más años', '75 y más años', '80 y más años',
#        '85 y más años', '90 y más años', '95 y más años',
#        '100 y más años'], dtype=object)

# %%
b
# Out:
# array([20.08, 14.7 ,  9.98,  6.08,  3.41,  1.27,  0.29,  0.03])

# %%
df2
# Out:
#         Provincias           Edad  Periodo  Total  Porcentaje
# 0   Total Nacional  65 y más años     2022  20,08       20.08
# 1   Total Nacional  65 y más años     2021  19,77       19.77
# 2   Total Nacional  65 y más años     2020  19,58       19.58
# 3   Total Nacional  65 y más años     2019  19,40       19.40
# 4   Total Nacional  65 y más años     2018  19,20       19.20
# 5   Total Nacional  65 y más años     2017  18,96       18.96
# 6   Total Nacional  65 y más años     2016  18,72       18.72
# 7   Total Nacional  65 y más años     2015  18,50       18.50
# 8   Total Nacional  65 y más años     2014  18,15       18.15
# 9   Total Nacional  65 y más años     2013  17,68       17.68
# 10  Total Nacional  65 y más años     2012  17,36       17.36
# 11  Total Nacional  65 y más años     2011  17,11       17.11
# 12  Total Nacional  65 y más años     2010  16,80       16.80
# 13  Total Nacional  65 y más años     2009  16,56       16.56
# ...

# %%
s = df['Edad'] == '65 y más años'

# %%
s2 = df['Provincias'] == 'Total Nacional'

# %%
df2 = df[s & s2]

# %%
c = df2['Porcentaje'].values

# %%
d = df2['Periodo'].values

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (10,8))
ax.barh(d,c)
ax.set_title('Porcentaje población con 65 años o más')
ax.set_xlabel('%')
ax.set_ylabel('Periodo')
ax.grid(axis='x')
plt.yticks(np.arange(1976,2023,2))
None

# %%
import numpy as np

# %%
dfp['Provincias'].values
# Out:
# array(['Total Nacional', 'Total Nacional', 'Total Nacional', ...,
#        '52 Melilla', '52 Melilla', '52 Melilla'], dtype=object)

# %%
dfp[dfp['Provincias'] == 'Total Nacional']
# Out:
#         Provincias           Edad  Periodo  Total  Porcentaje
# 0   Total Nacional  65 y más años     2022  20,08       20.08
# 1   Total Nacional  65 y más años     2021  19,77       19.77
# 2   Total Nacional  65 y más años     2020  19,58       19.58
# 3   Total Nacional  65 y más años     2019  19,40       19.40
# 4   Total Nacional  65 y más años     2018  19,20       19.20
# 5   Total Nacional  65 y más años     2017  18,96       18.96
# 6   Total Nacional  65 y más años     2016  18,72       18.72
# 7   Total Nacional  65 y más años     2015  18,50       18.50
# 8   Total Nacional  65 y más años     2014  18,15       18.15
# 9   Total Nacional  65 y más años     2013  17,68       17.68
# 10  Total Nacional  65 y más años     2012  17,36       17.36
# 11  Total Nacional  65 y más años     2011  17,11       17.11
# 12  Total Nacional  65 y más años     2010  16,80       16.80
# 13  Total Nacional  65 y más años     2009  16,56       16.56
# ...

# %%
s3 = df['Periodo'] == 2022

# %%
s = df['Edad'] == '65 y más años'

# %%
len(años)
# Out:
# 48

# %%
años = df[(df['Provincias'] == 'Total Nacional') & s]['Periodo'].values
for prov in df[s & (df['Periodo'] == 2022)]['Provincias'].values:
    seleccion = df[(df['Provincias'] == prov) & s]
    porcentaje = seleccion['Porcentaje'].values
    fig, ax = plt.subplots()
    ax.barh(años,porcentaje)
    ax.set_title(f'Porcentaje población con 65 años o más en {prov.split()[1]}')
    ax.set_xlabel('%')
    ax.set_ylabel('Periodo')
    ax.grid(axis='x')
    plt.yticks(np.arange(1976,2023,2))
    plt.xticks(np.arange(0,30,2))
    None
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_23392\1317916742.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
df[s & (df['Periodo'] == 2022)]['Provincias'].values
# Out:
# array(['Total Nacional', '02 Albacete', '03 Alicante/Alacant',
#        '04 Almería', '01 Araba/Álava', '33 Asturias', '05 Ávila',
#        '06 Badajoz', '07 Balears, Illes', '08 Barcelona', '48 Bizkaia',
#        '09 Burgos', '10 Cáceres', '11 Cádiz', '39 Cantabria',
#        '12 Castellón/Castelló', '13 Ciudad Real', '14 Córdoba',
#        '15 Coruña, A', '16 Cuenca', '20 Gipuzkoa', '17 Girona',
#        '18 Granada', '19 Guadalajara', '21 Huelva', '22 Huesca',
#        '23 Jaén', '24 León', '25 Lleida', '27 Lugo', '28 Madrid',
#        '29 Málaga', '30 Murcia', '31 Navarra', '32 Ourense',
#        '34 Palencia', '35 Palmas, Las', '36 Pontevedra', '26 Rioja, La',
#        '37 Salamanca', '38 Santa Cruz de Tenerife', '40 Segovia',
#        '41 Sevilla', '42 Soria', '43 Tarragona', '44 Teruel', '45 Toledo',
#        '46 Valencia/València', '47 Valladolid', '49 Zamora',
#        '50 Zaragoza', '51 Ceuta', '52 Melilla'], dtype=object)

# %%
df
# Out:
#            Provincias            Edad  Periodo  Total  Porcentaje
# 0      Total Nacional   65 y más años     2022  20,08       20.08
# 1      Total Nacional   65 y más años     2021  19,77       19.77
# 2      Total Nacional   65 y más años     2020  19,58       19.58
# 3      Total Nacional   65 y más años     2019  19,40       19.40
# 4      Total Nacional   65 y más años     2018  19,20       19.20
# ...               ...             ...      ...    ...         ...
# 20347      52 Melilla  100 y más años     1979   0,02        0.02
# 20348      52 Melilla  100 y más años     1978   0,02        0.02
# 20349      52 Melilla  100 y más años     1977   0,02        0.02
# 20350      52 Melilla  100 y más años     1976   0,02        0.02
# 20351      52 Melilla  100 y más años     1975   0,02        0.02
#
# [20352 rows x 5 columns]
